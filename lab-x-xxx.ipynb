# %% [markdown]
# # Title <hr style="border:2px solid #ff0000 "><hr>

# %% [markdown]
# <b>Daniel A Udasco</b>
# <br>3rd Year Comp Eng Tech Student

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Import "title.csv" Dataset

# %%
df = pd.read_csv(r"unprocessed/title.csv",
                 delimiter=",")
df
